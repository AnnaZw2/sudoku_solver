# %%
test_parameters(1000, 40, 10000, 15, "sss", "two_points", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "two_points", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "two_points", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "two_points", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "two_points", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "two_points", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "two_points", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "two_points", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "uniform", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "uniform", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "uniform", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "uniform", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "uniform", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "uniform", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "scattered", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "scattered", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "scattered", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "scattered", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "scattered", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "scattered", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "sss", "uniform", "random", 4,"saturate_50")






test_parameters(1000, 40, 10000, 15, "rws", "two_points", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "two_points", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "two_points", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "two_points", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "two_points", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "two_points", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "two_points", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "uniform", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "uniform", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "uniform", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "uniform", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "uniform", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "uniform", "random", 4,"saturate_50")

test_parameters(1000, 40, 10000, 15, "rws", "scattered", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "scattered", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "scattered", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "scattered", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "scattered", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "scattered", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rws", "uniform", "random", 4,"saturate_50")


test_parameters(1000, 40, 10000, 15, "rank", "two_points", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "two_points", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "two_points", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "two_points", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "two_points", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "two_points", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "two_points", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "uniform", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "uniform", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "uniform", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "uniform", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "uniform", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "uniform", "random", 4,"saturate_50")

test_parameters(1000, 40, 10000, 15, "rank", "scattered", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "scattered", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "scattered", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "scattered", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "scattered", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "scattered", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "rank", "uniform", "random", 4,"saturate_50")



test_parameters(1000, 40, 10000, 15, "random", "two_points", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "two_points", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "two_points", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "two_points", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "two_points", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "two_points", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "two_points", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "uniform", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "uniform", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "uniform", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "uniform", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "uniform", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "uniform", "random", 4,"saturate_50")

test_parameters(1000, 40, 10000, 15, "random", "scattered", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "scattered", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "scattered", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "scattered", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "scattered", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "scattered", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "random", "uniform", "random", 4,"saturate_50")





test_parameters(1000, 40, 10000, 15, "tournament", "two_points", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "two_points", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "two_points", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "two_points", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "two_points", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "two_points", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "two_points", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "uniform", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "uniform", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "uniform", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "uniform", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "uniform", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "uniform", "random", 4,"saturate_50")

test_parameters(1000, 40, 10000, 15, "tournament", "scattered", "inversion", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "scattered", "random", 15,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "scattered", "inversion", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "scattered", "random", 30,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "scattered", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "scattered", "random", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "uniform", "inversion", 4,"saturate_50")
test_parameters(1000, 40, 10000, 15, "tournament", "uniform", "random", 4,"saturate_50")
